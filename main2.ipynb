# %%
import re
import tweepy, json
from textblob import TextBlob
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#essential tokens for the api key 
consumer_key = "ZkgU51x7ZOC33hv3CMK4pWNsh"
consumer_secret = "OrPHe9zgm8GUUzcFUNe42LCuvXsvfjCq5HtYYdansgQbQpSfcp"
access_token = "1500395818062209024-1RX0bLbHUXyiWqK5XXQSL8lZt2VG5w"
access_token_secret = "1I4JK9EMw3t8mF6A8qSZWKHOl5snSJ1p3sbI67FFZVHmu"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
tweets = tweepy.Cursor(api.search_tweets, q="Covid-19", lang="en", tweet_mode="extended").items(500)
# tweets = api.search_tweets('Covid-19 Third wave', tweet_mode = "extended", until=2021-12-15).items(500)
# print(dir(tweets))
for i in tweets:
  print(i.full_text)

file = open("data.csv")
# Out:
# RT @LloydCymru: As part of my Welsh Bacc, I am running a survey about COVID-19. If you live in Wales, or have spent a significant amount of…
# RT @NHSuk: If you have COVID-19 symptoms, you should avoid contact with others and order a PCR test.
#
# If you test positive, stay at home.…
# This will be observed until February 6, 2022, and further update will be shared based on the COVID-19 assessment on the ground. Finally, we urge everyone to get tested if you have any flu like symptoms.
# COVID-19 cases continue to decline, treatment options expand #Atascadero https://t.co/yiCKjKmHOb https://t.co/pIDuBuGK0u
# RT @60Minutes: Dr. Rochelle Walensky took @DrLaPook into the CDC’s Emergency Operations Center to show how the CDC monitors emerging diseas…
# RT @MeetJess: Ongoing 'immune injuries' might cause persistent breathlessness after COVID-19 https://t.co/7428H2O10h
# ...

# %%
#writting a csv file 
file = open("data.csv", 'w')
file.write(str(
    for i in tweets:
        print(i.full_text)
    ))
file.close()
# Out:
#   File "C:\Users\peeyu\AppData\Local\Temp\ipykernel_5036\2658951969.py", line 4
#     for i in tweets:
#       ^
# SyntaxError: invalid syntax
